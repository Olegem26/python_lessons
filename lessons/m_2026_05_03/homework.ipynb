# %%
123
# Out:
# 123

# %%
import time
from datetime import datetime

# %%
now_time = time.time()
print(now_time)
# Out:
# 1778397069.878597

# %%
time_str = '2026-05-10'
now_datetime = datetime.strptime(time_str, '%Y-%m-%d')
now_datetime
# Out:
# datetime.datetime(2026, 5, 10, 0, 0)

# %%
now_datetime = datetime.fromtimestamp(now_time)
now_datetime
# Out:
# datetime.datetime(2026, 5, 10, 10, 11, 9, 878597)

# %%
time_str = '15/03/2025'
time_datetime = datetime.strptime(time_str, '%d/%m/%Y')
time_datetime
# Out:
# datetime.datetime(2025, 3, 15, 0, 0)

# %%
time_datetime.year
# Out:
# 2025

# %%
time_str[6:]
# Out:
# '2025'
