# %%
def get_rhomb(h, char = '-'):

    rhomb = ''

    for i in range(h):
        spaces = (h - i) - 1
        stars = (2 * i) + 1
        row = ' ' * spaces + char * stars + '\n'
        rhomb += row
    for i in range((h - 1) - 1, 0 - 1, -1):
        spaces = (h - i) - 1
        stars = (2 * i) + 1
        row = ' ' * spaces + char * stars + '\n'
        rhomb += row

    return rhomb

# %%
result = get_rhomb(3)
print(result)
# Out:
#   -
#  ---
# -----
#  ---
#   -

# %%
def get_rhomb(h, char = '-', text = 'возвращаем ромб'):
    print(text)
    rhomb = ''

    for i in range(h):
        spaces = (h - i) - 1
        stars = (2 * i) + 1
        row = ' ' * spaces + char * stars + '\n'
        rhomb += row
    for i in range((h - 1) - 1, 0 - 1, -1):
        spaces = (h - i) - 1
        stars = (2 * i) + 1
        row = ' ' * spaces + char * stars + '\n'
        rhomb += row

    return rhomb

# %%
result = get_rhomb(3)
print(result)
# Out:
# возвращаем ромб
#   -
#  ---
# -----
#  ---
#   -

# %%
result = get_rhomb(3, text = 'возвращаем ромб с высотой 3', char = '+')
print(result)
# Out:
# возвращаем ромб с высотой 3
#   +
#  +++
# +++++
#  +++
#   +

# %%
#int, float, str, bool, None, datetime, Decimal

# %%
number = int(7)

# %%
if number is True:
    print('Its int')

# %%
number is int
# Out:
# False

# %%
type(number)
# Out:
# int

# %%
isinstance(number,int)
# Out:
# True

# %%
print(number//2)
# Out:
# 3

# %%
print(number * 3)
print(number ** 2)
print(number % 2)
# Out:
# 21
# 49
# 1

# %%
print(number / 1)
# Out:
# 7.0

# %%
value_float = number / 1
print(value_float)
# Out:
# 7.0

# %%
isinstance(value_float,float)
# Out:
# True

# %%
value_float = float(2.5)
print(value_float)
isinstance(value_float, float)
# Out:
# 2.5
# True

# %%
1.0 + 2.0
# Out:
# 3.0

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
from decimal import Decimal

value_decimal = Decimal('0.1') + Decimal('0.2')
print(value_decimal)
isinstance(value_decimal,Decimal)
# Out:
# 0.3
# True

# %%
def is_int(value):
    true_or_false_bool = isinstance(value, int)
    return true_or_false_bool

# %%
is_int(8)
# Out:
# True

# %%
if is_int('number'):
    print('Работаем как с числом')
else:
    print('Это не число')
# Out:
# Это не число

# %%
value_string = '123'
print(value_string)
isinstance(value_string, str)
# Out:
# 123
# True

# %%
value_string[1:]
value_string[0]
value_string[:2]
# Out:
# '12'

# %%
none = None
isinstance(none,None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 none = None
# ----> 2 isinstance(none,None)
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union

# %%
type(None)
# Out:
# NoneType

# %%
isinstance(none, type(None))
# Out:
# True

# %%
'' == None
# Out:
# False

# %%
from time import time
print(time())
# Out:
# 1777795641.1090398
